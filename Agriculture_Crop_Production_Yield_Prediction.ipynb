# %%
import numpy as np
import pandas as pd
import statistics  as st
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("D:\\SIADataset.csv")

# %%
df

# %%
df.shape

# %%
df.info()

# %%
df.describe()

# %%
print(len(df.columns))
print(df.columns)

# %%
df.columns = ['Dist Code', 'Year', 'State Code', 'State_Name', 'Dist_Name',
       'RICE AREA (1000 ha)', 'RICE PRODUCTION (1000 tons)',
       'RICE YIELD (Kg per ha)', 'GROUNDNUT AREA (1000 ha)',
       'GROUNDNUT PRODUCTION (1000 tons)', 'GROUNDNUT YIELD (Kg per ha)',
       'SUGARCANE AREA (1000 ha)', 'SUGARCANE PRODUCTION (1000 tons)',
       'SUGARCANE YIELD (Kg per ha)', 'FRUITS AND VEGETABLES AREA (1000 ha)']

# %%
df.columns

# %%
df.drop("State Code",axis=1,inplace=True)

# %%
df

# %%
df_numeric=df.select_dtypes(include='number')

# %%
corelation_matrix=df_numeric.corr()

# %%
print(corelation_matrix)

# %%
plt.figure(figsize=(5,7))
sns.heatmap(df_numeric.corr())

# %%
sns.pairplot(df,hue='Year')

# %%
sns.pairplot(df,hue='State_Name')

# %%
sns.pairplot(df,hue='Dist_Name')

# %%
sns.pairplot(df,hue='RICE YIELD (Kg per ha)')

# %%
sns.pairplot(df,hue='GROUNDNUT YIELD (Kg per ha)')

# %%
sns.pairplot(df,hue='SUGARCANE YIELD (Kg per ha)')

# %%
sns.pairplot(df,hue='FRUITS AND VEGETABLES AREA (1000 ha)')

# %%
sns.pairplot(df,hue='RICE AREA (1000 ha)')

# %%
sns.pairplot(df,hue='GROUNDNUT AREA (1000 ha)')

# %%
sns.pairplot(df,hue='SUGARCANE AREA (1000 ha)')

# %%
sns.pairplot(df,hue='RICE PRODUCTION (1000 tons)')

# %%
sns.pairplot(df,hue='GROUNDNUT PRODUCTION (1000 tons)')

# %%
sns.pairplot(df,hue='SUGARCANE PRODUCTION (1000 tons)')

# %%
df.boxplot()

# %%
Q1 = np.percentile(df['Year'], 20,interpolation = 'midpoint')

# %%
Q3 = np.percentile(df['Dist Code'], 20,interpolation = 'midpoint')

# %%
IQR = Q3 - Q1

# %%
IQR

# %%
print("New Shape: ", df.shape)

# %%
df.boxplot()

# %%
plt.figure(figsize=(10,15))
plt.bar(df.State_Name,df.Dist_Name)
sns.barplot(x='State_Name',y='Dist_Name',data=df)
plt.show()

# %%
plt.figure(figsize=(10,15))
sns.barplot(x='State_Name',y='Dist_Name',data=df,hue='RICE YIELD (Kg per ha)')
plt.show()

# %%
plt.figure(figsize=(10,15))
sns.barplot(x='State_Name',y='Dist_Name',data=df,hue='GROUNDNUT YIELD (Kg per ha)')
plt.show()

# %%
plt.figure(figsize=(10,15))
sns.barplot(x='State_Name',y='Dist_Name',data=df,hue='SUGARCANE YIELD (Kg per ha)')
plt.show()

# %%
plt.figure(figsize=(10,15))
sns.barplot(x='State_Name',y='Dist_Name',data=df,hue='FRUITS AND VEGETABLES AREA (1000 ha)')
plt.show()

# %%
plt.figure(figsize=(10,15))
sns.barplot(x='State_Name',y='Dist_Name',data=df,hue='Year')
plt.show()

# %%
plt.figure(figsize=(10,15))
sns.barplot(x='State_Name',y='Year',data=df,hue='RICE YIELD (Kg per ha)')
plt.show()

# %%
plt.figure(figsize=(10,15))
sns.barplot(x='State_Name',y='Year',data=df,hue='GROUNDNUT YIELD (Kg per ha)')
plt.show()

# %%
plt.figure(figsize=(10,15))
sns.barplot(x='State_Name',y='Year',data=df,hue='SUGARCANE YIELD (Kg per ha)')
plt.show()

# %%
plt.figure(figsize=(10,15))
sns.barplot(x='State_Name',y='Year',data=df,hue='FRUITS AND VEGETABLES AREA (1000 ha)')
plt.show()

# %%
plt.figure(figsize=(10,15))
sns.barplot(x='Year',y='Dist_Name',data=df,hue='RICE YIELD (Kg per ha)')
plt.show()

# %%
plt.figure(figsize=(10,15))
sns.barplot(x='Year',y='Dist_Name',data=df,hue='GROUNDNUT YIELD (Kg per ha)')
plt.show()

# %%
plt.figure(figsize=(10,15))
sns.barplot(x='Year',y='Dist_Name',data=df,hue='SUGARCANE YIELD (Kg per ha)')
plt.show()

# %%
plt.figure(figsize=(10,15))
sns.barplot(x='Year',y='Dist_Name',data=df,hue='FRUITS AND VEGETABLES AREA (1000 ha)')
plt.show()
